# %%
from PageExtractor import *

# %%
img=io.imread('../Data set/grade sheet/1.jpg')
imageArr,notWarped=getPageWarped(img, thresh1=180)
show_images(imageArr,titles=['img','grayImg','thresholdedImg','imgWithContours','img','img'])
# Out:
# 4030    3024
# Max Area:  3229073.0
# Total Area: 12186720
# Condition:  True
# 4
