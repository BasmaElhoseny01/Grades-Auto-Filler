# %%
from commonfunctions import *
from import *

# %%
#1.Read img
# Syntax: cv2.imread(path, flag)
# path: A string representing the path of the image to be read.
# flag: It specifies the way in which image should be read. It’s default value is cv2.IMREAD_COLOR
# 1.cv2.IMREAD_COLOR: It specifies to load a color image. Any transparency of image will be neglected. It is the default flag. Alternatively, we can pass integer value 1 for this flag.
# 2.cv2.IMREAD_GRAYSCALE: It specifies to load an image in grayscale mode. Alternatively, we can pass integer value 0 for this flag.
img = cv.imread('image1.png')
plt.imshow(img/255)
# cv.imshow("image", img)
# Here, the matter is straight-forward. For every pixel, the same threshold value is applied.
# If the pixel value is smaller than the threshold, it is set to 0, otherwise it is set to a maximum value.
# The first argument is the source image, which should be a grayscale image. The second argument is the threshold 
# value which is used to classify the pixel values. The third argument is the maximum value which is assigned to pixel 
# values exceeding the threshold. OpenCV provides different types of thresholding which is given by the fourth parameter 
# of the function. Basic thresholding as described above is done by using the type cv.THRESH_BINARY. 
# ret1,thresh1 = cv.threshold(img,250,255,cv.THRESH_BINARY)#<127 =0 else set to max
# ret2,thresh2 = cv.threshold(img,200,255,cv.THRESH_BINARY)#<200 =0 else set to max
# ret3,thresh3 = cv.threshold(img,127,150,cv.THRESH_BINARY)#<200 =0 else set to max=200=>gray

# cv.imshow(thresh1)
# cv.imshow(thresh2)
# cv.imshow(thresh3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 8>()
#       1 #1.Read img
#       2 # Syntax: cv2.imread(path, flag)
#       3 # path: A string representing the path of the image to be read.
#       4 # flag: It specifies the way in which image should be read. It’s default value is cv2.IMREAD_COLOR
#       5 # 1.cv2.IMREAD_COLOR: It specifies to load a color image. Any transparency of image will be neglected. It is the default flag. Alternatively, we can pass integer value 1 for this flag.
#       6 # 2.cv2.IMREAD_GRAYSCALE: It specifies to load an image in grayscale mode. Alternatively, we can pass integer value 0 for this flag.
#       7 img = cv.imread('image1.png')
# ----> 8 plt.imshow(img)
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:456, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
# ...

# %%
def Show_Images(images,titles):
    # Create Figure
    fig=plt.figure(figsize=(20, 10))
    
    # Setting number of rows and columns
    columns=2 # 2columns
    rows=math.ceil(np.shape(images)[0]/columns) #No of rows    
    
    n=1 #Counter for the subplots order
    for image,title in zip(images,titles):
        #Add subplot @ order postion 
        fig.add_subplot(rows, columns, n)
        n+=1
        plt.axis('off')
        plt.title(title)
        plt.imshow(image)

def Read_RGB_Image(path):
    image=cv.imread(path,1)#cv2.IMREAD_COLOR: It specifies to load a color image. Any transparency of image will be neglected.
    # Converting BGR color to RGB color format
    RGB_img = cv.cvtColor(image, cv.COLOR_BGR2RGB)
    return RGB_img
        
#import cv2, numpy and matplotlib libraries
import numpy as np
import matplotlib.pyplot as plt
# img=cv.imread("cufe.png",1)
img=Read_RGB_Image('table1.jpg')
# RGB_img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
Show_Images([img],['CV'])

# img=io.imread('cufe.png')
# print(np.shape(img))

# img=io.imread('coffee.jpeg')
# print(np.shape(img))

# img=io.imread('table1.jpg')
# print(np.shape(img))

# img=io.imread('ex1.jpg')
# print(np.shape(img))


# img=io.imread('ex2.png')
# print(np.shape(img))

# img=io.imread('circuit.tif')
# print(np.shape(img))




# print(np.shape(img))
# plt.figure()
#Displaying image using plt.imshow() method
# plt.imshow(img)

# Converting BGR color to RGB color format
# RGB_img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
# plt.imshow(RGB_img)
# print("hello")
# io.imshow(img)
# Show_Images([img,RGB_img,RGB_img],['CV read BGR','Covert BGR to RGB','g'])

    
#This code is contributed by sheetal verma

# %%
print(5/2)
print(math.ceil(5/2))
# Out:
# 2.5
# 3
