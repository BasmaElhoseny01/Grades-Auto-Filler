# %%
from modules.GradesSheet import *

# %%
# Trainng Model (to be in the Genral Main Function)
from modules.SymbolTrain import SVMTraining

model=SVMTraining()
# Out:
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ./Data Set/Training Set/Square\021 (2).jpg
# ./Data Set/Training Set/Square\021.jpg
# ./Data Set/Training Set/Square\1020 (2).jpg
# ./Data Set/Training Set/Square\1020.jpg
# ./Data Set/Training Set/Square\1120 (2).jpg
# ./Data Set/Training Set/Square\1120.jpg
# ./Data Set/Training Set/Square\120 (2).jpg
# ./Data Set/Training Set/Square\120.jpg
# ./Data Set/Training Set/Square\1220 (2).jpg
# ./Data Set/Training Set/Square\1220.jpg
# ./Data Set/Training Set/Square\1320.jpg
# ./Data Set/Training Set/Square\1410.jpg
# ./Data Set/Training Set/Square\1420 (2).jpg
# ./Data Set/Training Set/Square\1420.jpg
# ./Data Set/Training Set/Square\1510.jpg
# ./Data Set/Training Set/Square\1520 (2).jpg
# ./Data Set/Training Set/Square\1520.jpg
# ./Data Set/Training Set/Square\1620 (2).jpg
# ./Data Set/Training Set/Square\1620.jpg
# ./Data Set/Training Set/Square\210.jpg
# ./Data Set/Training Set/Square\220 (2).jpg
# ./Data Set/Training Set/Square\220.jpg
# ./Data Set/Training Set/Square\320 (2).jpg
# ./Data Set/Training Set/Square\320.jpg
# ./Data Set/Training Set/Square\410.jpg
# ./Data Set/Training Set/Square\420 (2).jpg
# ./Data Set/Training Set/Square\420.jpg
# ./Data Set/Training Set/Square\520 (2).jpg
# ./Data Set/Training Set/Square\520.jpg
# ./Data Set/Training Set/Square\620 (2).jpg
# ./Data Set/Training Set/Square\620.jpg
# ./Data Set/Training Set/Square\720 (2).jpg
# ./Data Set/Training Set/Square\720.jpg
# ./Data Set/Training Set/Square\820 (2).jpg
# ./Data Set/Training Set/Square\820.jpg
# ./Data Set/Training Set/Square\920.jpg
# ./Data Set/Training Set/Horizontal/1\1210 (2).jpg
# ./Data Set/Training Set/Horizontal/1\1210 (3).jpg
# ./Data Set/Training Set/Horizontal/1\1210.jpg
# ./Data Set/Training Set/Horizontal/1\510 (2).jpg
# ./Data Set/Training Set/Horizontal/1\510.jpg
# ./Data Set/Training Set/Horizontal/1\5101.jpg
# ./Data Set/Training Set/Horizontal/2\1131.jpg
# ./Data Set/Training Set/Horizontal/2\1310.jpg
# ./Data Set/Training Set/Horizontal/2\300.jpg
# ./Data Set/Training Set/Horizontal/2\510 (2).jpg
# ./Data Set/Training Set/Horizontal/2\510.jpg
# ./Data Set/Training Set/Horizontal/2\630.jpg
# ./Data Set/Training Set/Horizontal/2\631.jpg
# ./Data Set/Training Set/Horizontal/2\710 (2).jpg
# ./Data Set/Training Set/Horizontal/2\710.jpg
# ./Data Set/Training Set/Horizontal/2\922.jpg
# ./Data Set/Training Set/Horizontal/3\110 (2).jpg
# ./Data Set/Training Set/Horizontal/3\110.jpg
# ./Data Set/Training Set/Horizontal/3\1100.jpg
# ./Data Set/Training Set/Horizontal/3\1110 (2).jpg
# ./Data Set/Training Set/Horizontal/3\1110.jpg
# ./Data Set/Training Set/Horizontal/3\1410 (2).jpg
# ./Data Set/Training Set/Horizontal/3\1410.jpg
# ./Data Set/Training Set/Horizontal/3\210 (2).jpg
# ./Data Set/Training Set/Horizontal/3\210 (3).jpg
# ./Data Set/Training Set/Horizontal/3\210.jpg
# ./Data Set/Training Set/Horizontal/4\810 (2).jpg
# ./Data Set/Training Set/Horizontal/4\810 (3).jpg
# ./Data Set/Training Set/Horizontal/4\810.jpg
# ./Data Set/Training Set/Vertical/1\100.jpg
# ./Data Set/Training Set/Vertical/1\1110.jpg
# ./Data Set/Training Set/Vertical/1\410 (2).jpg
# ./Data Set/Training Set/Vertical/1\410.jpg
# ./Data Set/Training Set/Vertical/1\610.jpg
# ./Data Set/Training Set/Vertical/2\1010 (2).jpg
# ./Data Set/Training Set/Vertical/2\1010.jpg
# ./Data Set/Training Set/Vertical/2\12132.jpg
# ./Data Set/Training Set/Vertical/2\1610.jpg
# ./Data Set/Training Set/Vertical/2\16110.jpg
# ./Data Set/Training Set/Vertical/2\610 (2).jpg
# ./Data Set/Training Set/Vertical/2\610.jpg
# ./Data Set/Training Set/Vertical/3\110 (2).jpg
# ./Data Set/Training Set/Vertical/3\110.jpg
# ./Data Set/Training Set/Vertical/3\12ff.jpg
# ./Data Set/Training Set/Vertical/3\1510 (2).jpg
# ./Data Set/Training Set/Vertical/3\1510.jpg
# ./Data Set/Training Set/Vertical/3\310 (2).jpg
# ./Data Set/Training Set/Vertical/3\310 (3).jpg
# ./Data Set/Training Set/Vertical/3\310.jpg
# ./Data Set/Training Set/Vertical/3\400.jpg
# ./Data Set/Training Set/Vertical/3\400d.jpg
# ./Data Set/Training Set/Vertical/3\910.jpg
# ./Data Set/Training Set/Vertical/3\asa.jpg
# ./Data Set/Training Set/Vertical/4\010.jpg
# ./Data Set/Training Set/Vertical/4\011 (2).jpg
# ./Data Set/Training Set/Vertical/4\011.jpg
# ./Data Set/Training Set/Vertical/4\1010.jpg
# ./Data Set/Training Set/Vertical/4\1200.jpg
# ./Data Set/Training Set/Vertical/4\1234.jpg
# ./Data Set/Training Set/Vertical/4\1234567.jpg
# ./Data Set/Training Set/Vertical/4\1610.jpg
# ./Data Set/Training Set/Vertical/4\333.jpg
# ./Data Set/Training Set/Vertical/5\0101.jpg
# ./Data Set/Training Set/Vertical/5\011.jpg
# ./Data Set/Training Set/Vertical/5\161210.jpg
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\numpy\core\_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# (5,)
# (4,)

# %%
# Predict 
from modules.SymbolDetector import SymbolValue
from modules.utils import *

img_1=cv2.imread('./CellsExtracted/1/710.jpg', cv2.IMREAD_GRAYSCALE)#Tick

SymbolValue(img_1,model)

img_1=cv2.imread('./CellsExtracted/1/520.jpg', cv2.IMREAD_GRAYSCALE)#Tick
SymbolValue(img_1,model)

# %%
GradesSheet('./Data set/grade sheet/1.jpg',index=1)

# %%
GradesSheet('./Data set/grade sheet/2.jpg')

# %%
GradesSheet('./Data set/grade sheet/3.jpg',index=3)

# %%
GradesSheet('./Data set/grade sheet/4.jpg',index=4)

# %%
GradesSheet('./Data set/grade sheet/5.jpg')

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/6.jpg')

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/7.jpg')

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/8.jpg',index=8)

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/9.jpg')

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/10.jpg')

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/11.jpg')

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/12.jpg')

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/13.jpg',SVM=model,index=13)
# Out:
# Max_Area 8542077.5
# Biggest Rectangle [[[ 395   19]]
#
#  [[ 346 3511]]
#
#  [[2801 3527]]
#
#  [[2853   83]]]
# Height*Width 12192768
# (4032, 3024)
# Boxes (72, 4)
# 174.20909090909092
# Rows
# [[2672, 218, 254, 56], [2410, 218, 253, 56], [2148, 219, 253, 55], [153, 219, 240, 56], [2672, 283, 254, 122], [2410, 284, 253, 122], [2148, 284, 253, 122], [153, 285, 237, 123]]
# [[2671, 413, 255, 124], [2409, 415, 253, 122], [2148, 415, 252, 122], [153, 416, 238, 122]]
# [[2671, 545, 254, 124], [2148, 546, 252, 123], [2409, 547, 253, 123], [154, 547, 237, 123]]
# [[2671, 677, 254, 122], [2410, 677, 252, 122], [2148, 677, 252, 121], [154, 677, 237, 122]]
# [[2148, 806, 253, 122], [2410, 807, 253, 121], [154, 807, 237, 122], [2671, 808, 254, 122]]
# [[2411, 936, 252, 122], [2148, 936, 254, 122], [2672, 937, 253, 123], [154, 937, 236, 122]]
# [[2411, 1066, 254, 123], [2149, 1066, 254, 122], [2673, 1067, 252, 123], [153, 1067, 237, 122]]
# [[2412, 1197, 253, 122], [2150, 1197, 254, 121], [2674, 1198, 252, 122], [152, 1198, 237, 121]]
# [[2413, 1327, 253, 122], [2150, 1327, 254, 122], [2675, 1328, 253, 122], [152, 1328, 237, 121]]
# [[2675, 1458, 253, 122], [2412, 1458, 255, 122], [2149, 1458, 255, 123], [152, 1458, 238, 121]]
# [[152, 1588, 238, 122], [2675, 1589, 254, 122], [2412, 1589, 255, 122], [2148, 1589, 256, 123]]
# [[152, 1719, 238, 122], [2675, 1720, 254, 122], [2411, 1720, 255, 122], [2147, 1721, 256, 122]]
# [[2675, 1850, 254, 123], [152, 1850, 239, 121], [2410, 1851, 256, 122], [2146, 1851, 256, 122]]
# [[2674, 1981, 255, 123], [2410, 1981, 256, 123], [152, 1981, 240, 121], [2145, 1982, 256, 122]]
# [[2674, 2112, 255, 124], [2410, 2112, 255, 123], [153, 2112, 239, 122], [2145, 2113, 256, 122]]
# [[153, 2242, 239, 123], [2674, 2243, 255, 123], [2410, 2243, 256, 123], [2145, 2243, 256, 122]]
# [[2674, 2374, 255, 123], [2409, 2374, 257, 122], [2145, 2374, 257, 122], [153, 2374, 239, 121]]
# (17,)
# Total Cells 4
# Center [2801, 2537, 2273, 272]
# Center [ 272 2273 2537 2801]
# [[[2148, 219, 253, 55], [2148, 284, 253, 122]], [[2410, 218, 253, 56], [2410, 284, 253, 122]], [[2672, 218, 254, 56], [2672, 283, 254, 122]], [[153, 219, 240, 56], [153, 285, 237, 123]]]
# [[[2148, 415, 252, 122]], [[2409, 415, 253, 122]], [[2671, 413, 255, 124]], [[153, 416, 238, 122]]]
# [[[2148, 546, 252, 123]], [[2409, 547, 253, 123]], [[2671, 545, 254, 124]], [[154, 547, 237, 123]]]
# [[[2148, 677, 252, 121]], [[2410, 677, 252, 122]], [[2671, 677, 254, 122]], [[154, 677, 237, 122]]]
# [[[2148, 806, 253, 122]], [[2410, 807, 253, 121]], [[2671, 808, 254, 122]], [[154, 807, 237, 122]]]
# [[[2148, 936, 254, 122]], [[2411, 936, 252, 122]], [[2672, 937, 253, 123]], [[154, 937, 236, 122]]]
# [[[2149, 1066, 254, 122]], [[2411, 1066, 254, 123]], [[2673, 1067, 252, 123]], [[153, 1067, 237, 122]]]
# [[[2150, 1197, 254, 121]], [[2412, 1197, 253, 122]], [[2674, 1198, 252, 122]], [[152, 1198, 237, 121]]]
# [[[2150, 1327, 254, 122]], [[2413, 1327, 253, 122]], [[2675, 1328, 253, 122]], [[152, 1328, 237, 121]]]
# [[[2149, 1458, 255, 123]], [[2412, 1458, 255, 122]], [[2675, 1458, 253, 122]], [[152, 1458, 238, 121]]]
# [[[2148, 1589, 256, 123]], [[2412, 1589, 255, 122]], [[2675, 1589, 254, 122]], [[152, 1588, 238, 122]]]
# [[[2147, 1721, 256, 122]], [[2411, 1720, 255, 122]], [[2675, 1720, 254, 122]], [[152, 1719, 238, 122]]]
# [[[2146, 1851, 256, 122]], [[2410, 1851, 256, 122]], [[2675, 1850, 254, 123]], [[152, 1850, 239, 121]]]
# [[[2145, 1982, 256, 122]], [[2410, 1981, 256, 123]], [[2674, 1981, 255, 123]], [[152, 1981, 240, 121]]]
# [[[2145, 2113, 256, 122]], [[2410, 2112, 255, 123]], [[2674, 2112, 255, 124]], [[153, 2112, 239, 122]]]
# [[[2145, 2243, 256, 122]], [[2410, 2243, 256, 123]], [[2674, 2243, 255, 123]], [[153, 2242, 239, 123]]]
# [[[2145, 2374, 257, 122]], [[2409, 2374, 257, 122]], [[2674, 2374, 255, 123]], [[153, 2374, 239, 121]]]
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\numpy\core\_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['Question']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['4_ver']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['Question']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['Square']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['Square']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['Square']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['3_hor']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['Square']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['3_ver']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['Square']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['1_ver']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['Square']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['1_hor']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['Square']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['2_ver']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['Square']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['2_hor']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['Square']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['4_hor']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['Square']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['3_ver']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['Square']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['2_ver']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['Square']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['1_ver']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['Square']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['1_hor']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['Square']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['2_hor']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['Square']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['3_hor']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['Square']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['3_ver']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['Square']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['4_ver']
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ['Square']

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/14.jpg')

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/15.jpg',index=15)
