# %%
from modules.GradesSheet import *

# %%
GradesSheet('./Data set/grade sheet/1.jpg')
# Out:
# Max_Area 3221437.0
# Biggest Rectangle [[[2601  332]]
#
#  [[ 359  402]]
#
#  [[ 354 1805]]
#
#  [[2648 1767]]]
# Height*Width 12186720
# (4030, 3024)

# %%
GradesSheet('./Data set/grade sheet/2.jpg')
# Out:
# Max_Area 565064.5
# Biggest Rectangle [[[680  59]]
#
#  [[ 71  69]]
#
#  [[ 42 948]]
#
#  [[698 960]]]
# Height*Width 786432
# (1024, 768)

# %%
GradesSheet('./Data set/grade sheet/3.jpg')
# Out:
# Max_Area 659688.0
# Biggest Rectangle [[[ 22  22]]
#
#  [[  6 985]]
#
#  [[703 985]]
#
#  [[691  28]]]
# Height*Width 786432
# (1024, 768)

# %%
GradesSheet('./Data set/grade sheet/4.jpg')
# Out:
# Max_Area 641530.5
# Biggest Rectangle [[[ 38  19]]
#
#  [[ 10 969]]
#
#  [[702 972]]
#
#  [[694  29]]]
# Height*Width 786432
# (1024, 768)

# %%
GradesSheet('./Data set/grade sheet/5.jpg')
# Out:
# Max_Area 7997280.0
# Biggest Rectangle [[[ 422  317]]
#
#  [[ 162 3705]]
#
#  [[2869 3617]]
#
#  [[2557  416]]]
# Height*Width 12192768
# (4032, 3024)

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/6.jpg')
# Out:
# Max_Area 4689.5
# Biggest Rectangle [[[2557 2048]]
#
#  [[2478 2052]]
#
#  [[2480 2104]]
#
#  [[2562 2105]]]
# Height*Width 12192768
# (4032, 3024)
# Contours Failed to get Page

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/7.jpg')
# Out:
# Max_Area 6955481.5
# Biggest Rectangle [[[2337  521]]
#
#  [[ 366  693]]
#
#  [[ 418 3805]]
#
#  [[2948 3501]]]
# Height*Width 12192768
# (4032, 3024)

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/8.jpg')
# Out:
# Max_Area 9118222.5
# Biggest Rectangle [[[2763  201]]
#
#  [[ 292  248]]
#
#  [[ 257 3802]]
#
#  [[2867 3802]]]
# Height*Width 12192768
# (4032, 3024)

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/9.jpg')
# Out:
# Max_Area 8525922.0
# Biggest Rectangle [[[ 316  235]]
#
#  [[ 161 3719]]
#
#  [[2888 3619]]
#
#  [[2570  261]]]
# Height*Width 12192768
# (4032, 3024)

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/10.jpg')

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/11.jpg')

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/12.jpg')

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/13.jpg')

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/14.jpg')

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/15.jpg')
