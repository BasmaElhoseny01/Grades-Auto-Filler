# %%
from modules.GradesSheet import *

# %%
from modules.DigitsTrain import DigitKNN
DigitKNN()

# %%
# Trainng Model (to be in the Genral Main Function)
from modules.SymbolTrain import SVMTraining

model=SVMTraining()
# Out:
# ./Data Set/Training Set/Tick\011.jpg
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ./Data Set/Training Set/Tick\110.jpg
# ./Data Set/Training Set/Tick\210.jpg
# ./Data Set/Training Set/Tick\310.jpg
# ./Data Set/Training Set/Tick\510.jpg
# ./Data Set/Training Set/Tick\610.jpg
# ./Data Set/Training Set/Tick\710.jpg
# ./Data Set/Training Set/Tick\720.jpg
# ./Data Set/Training Set/Tick\810.jpg
# ./Data Set/Training Set/Tick\910.jpg
# ./Data Set/Training Set/QuestionMark\120.jpg
# ./Data Set/Training Set/QuestionMark\1210.jpg
# ./Data Set/Training Set/QuestionMark\1310.jpg
# ./Data Set/Training Set/QuestionMark\1710.jpg
# ./Data Set/Training Set/QuestionMark\220.jpg
# ./Data Set/Training Set/QuestionMark\310.jpg
# ./Data Set/Training Set/QuestionMark\320.jpg
# ...

# %%
# Trainng Model (to be in the Genral Main Function)
from modules.DigitsTrain import DigitTraining

Digitsmodel=DigitTraining()
# Out:
# ./Data Set/Training Set/numbers/0\800 (2).jpg
# C:\Users\Dell\AppData\Roaming\Python\Python39\site-packages\skimage\_shared\utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# ./Data Set/Training Set/numbers/0\800.jpg
# ./Data Set/Training Set/numbers/1\000.jpg
# ./Data Set/Training Set/numbers/1\900.jpg
# ./Data Set/Training Set/numbers/2\001.jpg
# ./Data Set/Training Set/numbers/2\010.jpg
# ./Data Set/Training Set/numbers/2\1000 (2).jpg
# ./Data Set/Training Set/numbers/2\1000.jpg
# ./Data Set/Training Set/numbers/3\1100.jpg
# ./Data Set/Training Set/numbers/4\1200 (2).jpg
# ./Data Set/Training Set/numbers/4\1200.jpg
# ./Data Set/Training Set/numbers/4\200 (2).jpg
# ./Data Set/Training Set/numbers/4\200.jpg
# ./Data Set/Training Set/numbers/5\300 (2).jpg
# ./Data Set/Training Set/numbers/5\300.jpg
# ./Data Set/Training Set/numbers/6\1400.jpg
# ...

# %%
# Predict 
from modules.SymbolDetector import SymbolValue
from modules.utils import *

img_1=cv2.imread('./CellsExtracted/1/220.jpg', cv2.IMREAD_GRAYSCALE)#Tick
img_1=img_1[20:np.shape(img_1)[0]-20,20:np.shape(img_1)[1]-20]
print(np.shape(img_1==250))
print(np.sum(img_1))

print(img_1)

show_images([img_1],"asdfb")
# SymbolValue(img_1,model)

img_1=cv2.imread('./CellsExtracted/1/520.jpg', cv2.IMREAD_GRAYSCALE)#Tick
# SymbolValue(img_1,model)

# %%
# Predict 
from modules.SymbolDetector import DigitValue
from modules.utils import *

img_1=cv2.imread('./Data set/Training Set/numbers/1/900.jpg', cv2.IMREAD_GRAYSCALE)#2
show_images([img_1],"asdfb")
DigitValue(img_1,Digitsmodel)

img_1=cv2.imread('./CellsExtracted/1/900.jpg', cv2.IMREAD_GRAYSCALE)#9
show_images([img_1],"asdfb")
DigitValue(img_1,Digitsmodel)

img_1=cv2.imread('./CellsExtracted/1/1000.jpg', cv2.IMREAD_GRAYSCALE)#0
show_images([img_1],"asdfb")
DigitValue(img_1,Digitsmodel)


img_1=cv2.imread('./CellsExtracted/1/1700.jpg', cv2.IMREAD_GRAYSCALE)#5
show_images([img_1],"asdfb")
DigitValue(img_1,Digitsmodel)


img_1=cv2.imread('./CellsExtracted/1/900.jpg', cv2.IMREAD_GRAYSCALE)#0
show_images([img_1],"asdfb")
DigitValue(img_1,Digitsmodel)

# %%
data=["","","","./Data set/grade sheet/1.jpg",1,True]
GradesSheet(data,SVM=model,DSVM=Digitsmodel)
# Out:
# Max_Area 3221437.0
# Biggest Rectangle [[[2601  332]]
#
#  [[ 359  402]]
#
#  [[ 354 1805]]
#
#  [[2648 1767]]]
# Height*Width 12186720
# (4030, 3024)
# Boxes (72, 4)
# 201.94927536231884
# Rows
# [[2752, 20, 263, 144], [12, 24, 259, 144], [2480, 25, 262, 144], [2209, 30, 262, 140]]
# [[2751, 179, 263, 215], [13, 184, 260, 214], [2480, 186, 262, 211], [2209, 188, 262, 209]]
# [[2751, 407, 263, 213], [2480, 412, 261, 211], [2210, 413, 260, 210], [15, 414, 259, 211]]
# [[2751, 635, 262, 212], [2480, 639, 261, 209], [2210, 639, 261, 209], [16, 642, 258, 210]]
# [[2751, 862, 261, 211], [2210, 862, 261, 210], [2480, 864, 261, 209], [16, 866, 258, 212]]
# [[2211, 1086, 260, 210], [2751, 1087, 261, 211], [2481, 1090, 260, 207], [16, 1094, 258, 209]]
# [[2211, 1310, 261, 210], [2481, 1313, 261, 209], [2752, 1314, 260, 209], [16, 1319, 257, 208]]
# [[2211, 1536, 261, 209], [2482, 1538, 261, 208], [2752, 1539, 261, 208], [16, 1543, 257, 209]]
# ...

# %%
GradesSheet('./Data set/grade sheet/2.jpg')

# %%
GradesSheet('./Data set/grade sheet/3.jpg',index=3)

# %%
GradesSheet('./Data set/grade sheet/4.jpg',index=4)

# %%
GradesSheet('./Data set/grade sheet/5.jpg')

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/6.jpg')

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/7.jpg')

# %%
from modules.GradesSheet import *
data=["","","","./Data set/grade sheet/8.jpg",8,True]
GradesSheet(data,SVM=model,DSVM=Digitsmodel)

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/9.jpg')

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/10.jpg')

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/11.jpg')

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/12.jpg')

# %%
from modules.GradesSheet import *
data=["","","","./Data set/grade sheet/13.jpg",13,True]
GradesSheet(data,SVM=model,DSVM=Digitsmodel)

# %%
from modules.GradesSheet import *
GradesSheet('./Data set/grade sheet/14.jpg')

# %%
from modules.GradesSheet import *
data=["","","","./Data set/grade sheet/15.jpg",15,True]
GradesSheet(data,SVM=model,DSVM=Digitsmodel)
